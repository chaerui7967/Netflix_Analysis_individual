# %%
import pandas as pd
import numpy as np
import datetime
import time
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

np.warnings.filterwarnings('ignore')

# %% [markdown]
# # 데이터 준비
# - 컬럼삭제 및 널값제거

# %%
df = pd.read_csv('use_df.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Series or Movie', 'COUNTRY', 'Release Date',
#        'GENRE', 'VALUE', 'Genre_all', 'Tags', 'Languages', 'Hidden Gem Score',
#        'Country Availability', 'Runtime', 'Director', 'Writer', 'Actors',
#        'View Rating', 'IMDb Score', 'Rotten Tomatoes Score',
#        'Metacritic Score', 'Awards Received', 'Awards Nominated For',
#        'Boxoffice', 'Netflix Release Date', 'Production House', 'Summary',
#        'IMDb Votes'],
#       dtype='object')

# %%
df.drop(columns=['Genre_all','IMDb Votes','Metacritic Score','Rotten Tomatoes Score','View Rating','COUNTRY','Country Availability','Unnamed: 0','Tags','Actors','Languages','Director','Writer','Boxoffice','Production House','Summary','Awards Nominated For','Runtime','IMDb Score','Hidden Gem Score'],axis=1,inplace=True)
df.head(1)
# Out:
#              Title Series or Movie  ... Awards Received Netflix Release Date
# 0  thequeensgambit              TV  ...            96.0           2020-10-23
#
# [1 rows x 7 columns]

# %%
df.columns=(['Title', 'Type', 'Made_date', 'Genre', 'Value','Awards_Received','Netflix_date'])

# %%
# 널값확인
import missingno as msno
color= ['dimgrey','dimgrey','maroon','maroon','dimgrey','red','dimgrey']
msno.bar(df,fontsize=10,color=color,figsize=(10,3))
plt.title('MISSING VALUES',fontsize=20)
# Out:
# Text(0.5, 1.0, 'MISSING VALUES')

# %%
df.isnull().sum()
# Out:
# Title                 0
# Type                  0
# Made_date            65
# Genre               377
# Value                 0
# Awards_Received    1502
# Netflix_date          0
# dtype: int64

# %%
# 장르 부분은 나중에 필요시 널값 제거
#Release Date 컬럼 널값 행 제거
df.dropna(subset=['Made_date'], inplace=True)
# Awards_Received 컬럼 널값 0으로 수정
df.Awards_Received.fillna('0',inplace=True)

# %%
df.isnull().sum(), df.shape
# Out:
# (Title                0
#  Type                 0
#  Made_date            0
#  Genre              322
#  Value                0
#  Awards_Received      0
#  Netflix_date         0
#  dtype: int64, (2913, 7))

# %%
netflix = df.copy()

# %%
netflix.duplicated().sum()
# 중복값 있으면 밑의 코드로 중복값 제거
# netflix_df = netflix.drop_duplicates(keep=False, inplace=False)
# Out:
# 0

# %% [markdown]
# ## 데이터 준비 - Netflix_date 인코딩
# - Year, Month, Day와 요일로 새로운 컬럼 확장

# %%
netflix["Netflix_date"] = pd.to_datetime(netflix['Netflix_date'])
netflix['Year'] = netflix['Netflix_date'].dt.year
netflix['Month'] = netflix['Netflix_date'].dt.month
netflix['Day'] = netflix['Netflix_date'].dt.day

netflix.head(1)
# Out:
#              Title Type   Made_date  Genre  ...  Netflix_date  Year Month  Day
# 0  thequeensgambit   TV  2020-10-23  Drama  ...    2020-10-23  2020    10   23
#
# [1 rows x 10 columns]

# %% [markdown]
# # 시각화
# - made_Date와 Netflix_Date 를 통해 만든 새로운 컬럼으로
# - 3-1 뷰어수와 넷플릭스 릴리즈 데이트 대한 상관관계
# - 3-1-2 넷플릭스 릴리즈 데이트를 해당날짜의 요일로 변경 후 요일별 컨텐츠 추가에 대한 viewporint와의 상관관계

# %%
plt.figure(figsize=(10,5))
plt.title('The percentage of movies and series in Netflix content')
g = plt.pie(netflix.Type.value_counts(),explode=(0.025,0.025),
            labels=df.Type.value_counts().index, colors=['red','grey'],
            autopct='%1.1f%%', startangle=200)
plt.show()

# %% [markdown]
# ### 가설
# - 귀무가설 : Netflix Release date 는 viewpoint에 영향이 있다
# - 대립가설 : Netflix Release date 는 viewpoint에 영향이 없다

# %%
# 무비, 시리즈 분리
Movie_df = netflix[netflix['Type']=='Movie']
Series_df = netflix[netflix['Type']=='TV']

# %%
Movie_df.head(1)
# Out:
#      Title   Type   Made_date    Genre  ...  Netflix_date  Year Month  Day
# 1  365days  Movie  2020-06-07  Romance  ...    2020-04-02  2020     4    2
#
# [1 rows x 10 columns]

# %%
Series_df.head(1)
# Out:
#              Title Type   Made_date  Genre  ...  Netflix_date  Year Month  Day
# 0  thequeensgambit   TV  2020-10-23  Drama  ...    2020-10-23  2020    10   23
#
# [1 rows x 10 columns]

# %% [markdown]
# #### 컨텐츠 추가 시기확인

# %%
fig, ax = plt.subplots(1,3, figsize=(20,6))
# 컨텐츠 추가 년,월,일별 통계
# Year
sns.countplot('Year', data=netflix, palette='vlag', ax=ax[0])
ax[0].set_title('Year added movie',
            fontdict={'fontsize':15})

# Month
sns.countplot('Month', data=netflix, palette='vlag', ax=ax[1])
ax[1].set_title('Month added movie',
            fontdict={'fontsize':15})

# Day
sns.countplot('Day', data=netflix, palette='vlag', ax=ax[2])
ax[2].set_title('Day added movie',
            fontdict={'fontsize':15})

plt.show()

# %% [markdown]
# - Year : 2015년과 2020년에 평균흐름보다 3배 가량의 컨텐츠 추가량이 보여진다
# - Month : 년초보단 하반기로 갈수록 점진적으로 많이 늘리는 흐름을 보이고, 4월은 다른달보다 컨텐츠 추가가 월등하게 높다
# - Day : 흐름을 고르게 보이고 있으나,1일과 14 일은 다른 날보다 많은 컨텐츠를 추가했다

# %% [markdown]
# ### 년, 월, 일 별 컨텐츠 추가날짜를 통한 Viewpoint 분석

# %%
netflix[netflix['Year']== 2015]['Value'].describe()
# Out:
# count      772.000000
# mean       319.715026
# std       1187.451960
# min          1.000000
# 25%         17.000000
# 50%         58.000000
# 75%        196.250000
# max      17782.000000
# Name: Value, dtype: float64

# %%
netflix[netflix['Year']== 2016]['Value'].describe()
# Out:
# count      183.000000
# mean       417.322404
# std       1702.986711
# min          1.000000
# 25%         15.500000
# 50%         62.000000
# 75%        213.000000
# max      20937.000000
# Name: Value, dtype: float64

# %%
len(netflix['Year'].unique())
# Out:
# 7

# %%
netflix['Year'].unique()
# Out:
# array([2020, 2017, 2019, 2016, 2015, 2018, 2021])

# %%
# 년도별 맥스
max = {}
for i in netflix['Year'].unique():
    max[i] = netflix[netflix['Year'] == i]['Value'].max()

max_df = pd.DataFrame(pd.Series(max)).reset_index()
max_df = max_df.sort_values('index')
max_df.columns = ['Year', 'Value']

# %%
max_df
# Out:
#    Year  Value
# 4  2015  17782
# 3  2016  20937
# 1  2017  25729
# 5  2018  10746
# 2  2019  23480
# 0  2020  44867
# 6  2021    917

# %%
# 맥스값 확인
print(netflix[netflix['Year'] == 2015]['Value'].max())
print(netflix[netflix['Year'] == 2016]['Value'].max())
print(netflix[netflix['Year'] == 2018]['Value'].max())
print(netflix[netflix['Year'] == 2019]['Value'].max())
print(netflix[netflix['Year'] == 2020]['Value'].max())
print(netflix[netflix['Year'] == 2021]['Value'].max())
# Out:
# 17782
# 20937
# 10746
# 23480
# 44867
# 917

# %%
# 월별
max_m = {}
for i in netflix['Month'].unique():
    max_m[i] = netflix[netflix['Month'] == i]['Value'].max()

maxM_df = pd.DataFrame(pd.Series(max_m)).reset_index()
maxM_df = maxM_df.sort_values('index')
maxM_df.columns = ['Month', 'Value']

# %%
# 일별
max_d = {}
for i in netflix['Day'].unique():
    max_d[i] = netflix[netflix['Day'] == i]['Value'].max()

maxD_df = pd.DataFrame(pd.Series(max_d)).reset_index()
maxD_df = maxD_df.sort_values('index')
maxD_df.columns = ['Day', 'Value']

# %%
fig, ax = plt.subplots(2,2, figsize=(15,5), dpi = 350)

sns.lineplot(x=max_df['Year'], y=max_df['Value'], data=netflix, ax=ax[0,0], alpha=0.7)
sns.lineplot(x=maxM_df['Month'], y=maxM_df['Value'], data=netflix, ax=ax[0,1], alpha=0.7)
sns.lineplot(x=maxD_df['Day'], y=maxD_df['Value'], data=netflix, ax=ax[1,0], alpha=0.7)
sns.lineplot(x='Netflix_date', y=netflix['Value'], data=netflix, ax=ax[1,1], alpha=0.7)

plt.show()

# %%
fig, ax = plt.subplots(2,2, figsize=(15,5))

sns.lineplot(x=netflix['Year'], y=netflix['Value'], data=netflix, ax=ax[0,0], alpha=0.7)
sns.lineplot(x='Month', y=netflix['Value'], data=netflix, ax=ax[0,1], alpha=0.7)
sns.lineplot(x='Day', y=netflix['Value'], data=netflix, ax=ax[1,0], alpha=0.7)
sns.lineplot(x='Netflix_date', y=netflix['Value'], data=netflix, ax=ax[1,1], alpha=0.7)

plt.show()

# %%
netflix.corr()
# Out:
#           Value      Year     Month       Day
# Value  1.000000  0.108651  0.044993  0.013330
# Year   0.108651  1.000000  0.330389  0.065654
# Month  0.044993  0.330389  1.000000  0.008790
# Day    0.013330  0.065654  0.008790  1.000000

# %% [markdown]
# - Year : 2020년에 추가된 컨텐츠와 2017년에 추가된 컨텐츠가 다른 년도에 추가된 컨텐츠보다 viewpoint 가 월등히 높음을 확인할 수 있다. 그럼 20년과 17년에 컨텐츠를 많이 출시 했을지 앞의 년도별 컨텐츠 추가량 그래프를 확인한 결과 20년은 굉장히 많은 컨텐츠를 출시 했지만 17년의 출시한 컨텐츠의 양은 평균 이하수준으로 확인된다
#
# - month : 10월과 7월에 추가한 컨텐츠가 다른 월에 출시한 컨텐츠보다 viewpoint 가 높음을 확인할 수 있다. 그럼 10월과 7월에 컨텐츠를 과도하게 많이 출시한건 아닐까? 앞서 분석한 월별 컨텐츠 추가량 그래프를 확인해보면 10월과 7월은 그다지 많이 출시하지 않았다.
#
# - Day : 매월 23-24일 사이에 출시된 컨텐츠의 viewpoint가 다른 일에 출시한 viewpoint 보다 월등히 높다. 앞서 day별 추가된 컨텐츠 량을 확인해 보면 1일과 14일에 추가된 컨텐츠의 양이 굉장히 높은걸로 확인된다.
#
# - 총평 :넷플릭스 출시 시기와 value(viewpoint)를 한눈에 볼수 있는 그래프가 있다 16년-17년 사이에 출시된 컨텐츠와 20년에 출시된 컨텐츠 들이 대체로 많은 viewpoint 를 기록 중이며, 출시가 빨리 됬다고 뷰포인트가 높은것은 아니다 라는 결론과 출시일정과 상관관계가 적다는 결론을 낼수 있다
#
# ### 그럼 여기서  조금 방향을 틀어보자. 어느 요일에 더 많은 컨텐츠를 출시 했는가?

# %%
#dayofweek(요일)컴럼 추가/ head 5개 값 확인 완료
netflix['dayofweek'] = netflix['Netflix_date'].dt.day_name()
netflix.head()
# Out:
#                 Title   Type   Made_date      Genre  ...  Year Month Day  dayofweek
# 0     thequeensgambit     TV  2020-10-23      Drama  ...  2020    10  23     Friday
# 1             365days  Movie  2020-06-07    Romance  ...  2020     4   2   Thursday
# 2        emilyinparis     TV  2020-10-02      Drama  ...  2020    10   2     Friday
# 3             lucifer     TV  2016-01-25  Superhero  ...  2017     7  24     Monday
# 4  theumbrellaacademy     TV  2019-02-15  Superhero  ...  2019     2  15     Friday
#
# [5 rows x 11 columns]

# %%
import plotly.express as px
day_df = netflix['dayofweek'].value_counts().reset_index()

fig = px.pie(day_df, values='dayofweek', names='index',color_discrete_sequence=px.colors.sequential.RdBu)
fig.update_traces(textposition='inside', textinfo='percent+label',
                  marker = dict(line = dict(color = 'white', width = 1)))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c54d610d-526f-4715-9753-854015996401" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c54d610d-526f-4715-9753-854015996401")) {
#                     Plotly.newPlot(
#                         'c54d610d-526f-4715-9753-854015996401',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "index=%{label}<br>dayofweek=%{value}", "labels": ["Tuesday", "Friday", "Wednesday", "Thursday", "Saturday", "Sunday", "Monday"], "legendgroup": "", "marker": {"line": {"color": "white", "width": 1}}, "name": "", "showlegend": true, "textinfo": "percent+label", "textposition": "inside", "type": "pie", "values": [860, 552, 393, 342, 283, 246, 237]}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "piecolorway": ["rgb(103,0,31)", "rgb(178,24,43)", "rgb(214,96,77)", "rgb(244,165,130)", "rgb(253,219,199)", "rgb(247,247,247)", "rgb(209,229,240)", "rgb(146,197,222)", "rgb(67,147,195)", "rgb(33,102,172)", "rgb(5,48,97)"], "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "ty ...

# %%
month_day=pd.crosstab(netflix['Month'],netflix['dayofweek'],margins=True).style.background_gradient(cmap='PuBu')
month_day
# Out:
# <style  type="text/css" >
# #T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row0_col0,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row0_col3,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row2_col4,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row3_col0,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row4_col7,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row7_col6,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row10_col5,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row10_col6{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row0_col1,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row0_col4,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row0_col5,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row1_col0,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row1_col2,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row1_col3,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row1_col5,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row1_col6,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row1_col7,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row2_col2,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row2_col6,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row3_col2,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row6_col5{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row0_col2,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row1_col4,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row2_col7,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row4_col1,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row4_col5,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row9_col5{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row0_col6,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row4_col6,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row8_col0,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row8_col4{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row0_col7,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row1_col1,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row5_col5{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row2_col0,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row2_col3,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row4_col4,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row5_col6,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row5_col7,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row6_col7,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row9_col3,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row9_col7,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row11_col5{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row2_col1,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row4_col2,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row6_col4,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row7_col0,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row9_col6,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row10_col1{
#             background-color:  #faf3f9;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row2_col5,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row7_col5{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row3_col1,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row8_col1{
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row3_col3,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row4_col3,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row6_col1,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row10_col7{
#             background-color:  #f6eff7;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row3_col4,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row4_col0,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row5_col0,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row7_col1{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row3_col5{
#             background-color:  #0f76b3;
#             color:  #f1f1f1;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row3_col6,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row10_col4{
#             background-color:  #f4edf6;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row3_col7{
#             background-color:  #d1d2e6;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row5_col1{
#             background-color:  #eae6f1;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row5_col2,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row6_col0,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row8_col6,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row11_col1,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row11_col7{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row5_col3,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row6_col2,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row8_col7{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row5_col4,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row6_col3,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row6_col6,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row9_col4,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row11_col4{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row7_col2{
#             background-color:  #eee8f3;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row7_col3{
#             background-color:  #ede8f3;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row7_col4,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row8_col5,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row9_col0,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row9_col2{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row7_col7{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row8_col2,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row10_col0{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row8_col3{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row9_col1{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row10_col2,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row11_col0{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row10_col3{
#             background-color:  #dedcec;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row11_col2{
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row11_col3{
#             background-color:  #eee9f3;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row11_col6{
#             background-color:  #f4eef6;
#             color:  #000000;
#         }#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row12_col0,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row12_col1,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row12_col2,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row12_col3,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row12_col4,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row12_col5,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row12_col6,#T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002row12_col7{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_aa49bc5e_e7b7_11eb_826f_0242ac1c0002" ><thead>    <tr>        <th class="index_name level0" >dayofweek</th>        <th class="col_heading level0 col0" >Friday</th>        <th class="col_heading level0 col1" >Monday</th>        <th class="col_heading level0 col2" >Saturday</th>        <th class="col_heading level0 col3" >Sunday</th>        <th class="col_heading level0 col4" >Thursd

# %% [markdown]
#  - 결과를 보면 넷플릭스의 컨텐츠 출시 요일은 목요일과 금요일이 압도적이다. 그럼 다음 그래프에선 출시 요일별 viewpoint를 한번 보도록하자

# %%
fig, ax = plt.subplots(2,2, figsize=(15,5))

sns.lineplot(x='Year', y=netflix['Value'], data=netflix, ax=ax[0,0], alpha=0.7)
sns.lineplot(x='Month', y=netflix['Value'], data=netflix, ax=ax[0,1], alpha=0.7)
sns.lineplot(x='Day', y=netflix['Value'], data=netflix, ax=ax[1,0], alpha=0.7)
sns.lineplot(x='dayofweek', y=netflix['Value'], data=netflix, ax=ax[1,1], alpha=0.7)

plt.show()

# %% [markdown]
# 총평 : 넷플릭스 출시 시기와 value(viewpoint)를 한눈에 볼수 있는 그래프가 있다
# 16년-17년 사이에 출시된 컨텐츠와 20년에 출시된 컨텐츠 들이 대체로 많은 viewpoint 를 기록 중이며, 출시가 빨리 됬다고 뷰포인트가 높은것은 아니다 라는 결론과 출시일정과 상관관계가 적다는 결론을 낼수 있고,
# 요일에 따른 viewpoint를 살펴보면 컨텐츠 출시는 대체적으로 화요일에 컨텐츠 출시를 많이 하고 있지만 목요일과 금요일에 출시한 컨텐츠들이 대체적으로 viewpoint가 높은것으로 나타난다
